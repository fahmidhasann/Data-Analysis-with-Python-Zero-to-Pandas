# %%
import pandas as pd

# %% [markdown]
# In this assignment, we're going to analyze an operate on data from a CSV file. Let's begin by downloading the CSV file.

# %%
from urllib.request import urlretrieve

urlretrieve('https://gist.githubusercontent.com/aakashns/28b2e504b3350afd9bdb157893f9725c/raw/994b65665757f4f8887db1c85986a897abb23d84/countries.csv',
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x7e460074e1a0>)

# %% [markdown]
# Let's load the data from the CSV file into a Pandas data frame.

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# **Q1: How many countries does the dataframe contain?**
#
# Hint: Use the `.shape` method.

# %%
countries_df.shape
# Out:
# (210, 6)

# %%
num_countries = 210

# %%
print('There are {} countries in the dataset'.format(num_countries))
# Out:
# There are 210 countries in the dataset

# %% [markdown]
# **Q2: Retrieve a list of continents from the dataframe?**
#
# *Hint: Use the `.unique` method of a series.*

# %%
continents = countries_df.continent.unique()

# %%
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **Q3: What is the total population of all the countries listed in this dataset?**

# %%
total_population = countries_df.population.sum()

# %%
print('The total population is {}.'.format(int(total_population)))
# Out:
# The total population is 7757980095.

# %% [markdown]
# **Q: (Optional) What is the overall life expectancy across in the world?**
#
# *Hint: You'll need to take a weighted average of life expectancy using populations as weights.*

# %%
average_life_expectsncy = countries_df.life_expectancy.sum()/len(countries_df.location)
average_life_expectsncy
# Out:
# 72.47942857142857

# %% [markdown]
# **Q4: Create a dataframe containing 10 countries with the highest population.**
#
# *Hint: Chain the `sort_values` and `head` methods.*

# %%
sorted_population=countries_df.sort_values('population')

# %%
most_populus_country=sorted_population.head(10)
most_populus_country
# Out:
#                             location      continent  population  \
# 203                          Vatican         Europe       809.0
# 65                  Falkland Islands  South America      3483.0
# 130                       Montserrat  North America      4999.0
# 5                           Anguilla  North America     15002.0
# 24   Bonaire Sint Eustatius and Saba  North America     26221.0
# 28            British Virgin Islands  North America     30237.0
# 75                         Gibraltar         Europe     33691.0
# 162                       San Marino         Europe     33938.0
# 113                    Liechtenstein         Europe     38137.0
# 194         Turks and Caicos Islands  North America     38718.0
#
#      life_expectancy  hospital_beds_per_thousand  gdp_per_capita
# 203            75.12                         NaN             NaN
# 65             81.44                         NaN             NaN
# 130            74.16                         NaN             NaN
# ...

# %% [markdown]
# **Q5: Add a new column in `countries_df` to record the overall GDP per country (product of population & per capita GDP).**

# %%
countries_df['gdp'] = countries_df.population * countries_df.gdp_per_capita

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %% [markdown]
# **Q: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.**

# %%
hundred_million_df = countries_df[countries_df.population>1e8]
hundred_million_df
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
lowest_gdp_per_capita = hundred_million_df.sort_values('gdp_per_capita')
lowest_gdp_per_capita
# Out:
#           location      continent    population  life_expectancy  \
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 145       Pakistan           Asia  2.208923e+08            67.27
# 141        Nigeria         Africa  2.061396e+08            54.69
# 90           India           Asia  1.380004e+09            69.66
# 151    Philippines           Asia  1.095811e+08            71.23
# 58           Egypt         Africa  1.023344e+08            71.99
# 91       Indonesia           Asia  2.735236e+08            71.72
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 125         Mexico  North America  1.289328e+08            75.05
# 157         Russia         Europe  1.459345e+08            72.58
# 99           Japan           Asia  1.264765e+08            84.63
# ...

# %%
sorted_lowest_gdp_per_capita = lowest_gdp_per_capita.head(10)
sorted_lowest_gdp_per_capita
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %% [markdown]
# **Q6: Create a data frame that counts the number countries in each continent?**
#
# *Hint: Use `groupby`, select the `location` column and aggregate using `count`.*

# %%
country_counts_df = countries_df.groupby('continent')['location'].count()

# %%
country_counts_df
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# **Q7: Create a data frame showing the total population of each continent.**
#
# *Hint: Use `groupby`, select the population column and aggregate using `sum`.*

# %%
continent_populations_df = countries_df.groupby('continent')['population'].sum()

# %%
continent_populations_df
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
# Let's download another CSV file containing overall Covid-19 stats for various countires, and read the data into another Pandas data frame.

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/b2a968a6cfd9fbbb0ff3d6bd0f26262b/raw/b115ed1dfa17f10fc88bf966236cd4d9032f1df8/covid-countries-data.csv',
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x7e45f7c298a0>)

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **Q8: Count the number of countries for which the `total_tests` data is missing.**
#
# *Hint: Use the `.isna` method.*

# %%
total_tests_missing = covid_data_df.total_tests.isna().sum()
total_tests_missing
# Out:
# 122

# %%
print("The data for total tests is missing for {} countries.".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 122 countries.

# %% [markdown]
# Let's merge the two data frames, and compute some more metrics.
#
# **Q9: Merge `countries_df` with `covid_data_df` on the `location` column.**
#
# *Hint: Use the `.merge` method on `countries_df`.

# %%
combined_df = covid_data_df.merge(countries_df,on='location')

# %%
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %% [markdown]
# **Q10: Add columns `tests_per_million`, `cases_per_million` and `deaths_per_million` into `combined_df`.**

# %%
combined_df['cases_per_million']= (combined_df.total_cases/combined_df.population)*1e6

# %%
combined_df['tests_per_million'] = (combined_df.total_tests/combined_df.population)*1e6

# %%
combined_df['deaths_per_million'] = (combined_df.total_deaths/combined_df.population)*1e6

# %%
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q11: Create a dataframe with 10 countires that have highest number of tests per million people.**

# %%
ten_highest_tests_df = combined_df.sort_values('tests_per_million',ascending=False)[['location','tests_per_million']].head(10)

# %%
ten_highest_tests_df
# Out:
#                  location  tests_per_million
# 197  United Arab Emirates      725696.635121
# 14                Bahrain      657527.137965
# 115            Luxembourg      616349.508607
# 122                 Malta      427004.183096
# 53                Denmark      422621.755488
# 96                 Israel      271962.665303
# 89                Iceland      260304.761905
# 157                Russia      254750.159763
# 199         United States      253467.507769
# 10              Australia      245326.517406

# %% [markdown]
# **Q12: Create a dataframe with 10 countires that have highest number of positive cases per million people.**

# %%
ten_highest_cases_df = combined_df.sort_values('cases_per_million',ascending=False)[['location','cases_per_million']].head(10)

# %%
ten_highest_cases_df
# Out:
#           location  cases_per_million
# 155          Qatar       41375.743650
# 14         Bahrain       30818.361490
# 147         Panama       21805.112117
# 40           Chile       21695.671982
# 162     San Marino       21657.139490
# 9            Aruba       20708.839893
# 105         Kuwait       20249.789079
# 150           Peru       20121.318048
# 27          Brazil       18808.224105
# 199  United States       18472.377957

# %% [markdown]
# **Q13: Create a dataframe with 10 countires that have highest number of deaths cases per million people?**

# %%
ten_highest_deaths_df = combined_df.sort_values('deaths_per_million',ascending=False)[['location','deaths_per_million']].head(10)

# %%
ten_highest_deaths_df
# Out:
#            location  deaths_per_million
# 162      San Marino         1237.550828
# 150            Peru          887.393445
# 18          Belgium          854.040375
# 3           Andorra          685.950948
# 177           Spain          624.406705
# 198  United Kingdom          611.525168
# 40            Chile          593.423100
# 97            Italy          587.097697
# 27           Brazil          582.331314
# 182          Sweden          576.279276

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".**

# %%
common_countries1=ten_highest_cases_df.merge(ten_highest_deaths_df,on='location',how='inner')
common_countries1.location.count()
# Out:
# 4

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.**

# %%
ten_million_population_df=combined_df[combined_df.population>1e7]
ten_million_population_df
# Out:
#         location  total_cases  total_deaths  total_tests      continent  \
# 0    Afghanistan      38243.0        1409.0          NaN           Asia
# 2        Algeria      45158.0        1525.0          NaN         Africa
# 4         Angola       2729.0         109.0          NaN         Africa
# 7      Argentina     428226.0        8971.0    1118923.0  South America
# 10     Australia      25923.0         663.0    6255797.0        Oceania
# ..           ...          ...           ...          ...            ...
# 204    Venezuela      48883.0         398.0          NaN  South America
# 205      Vietnam       1046.0          35.0     261004.0           Asia
# 207        Yemen       1976.0         571.0          NaN           Asia
# 208       Zambia      12415.0         292.0          NaN         Africa
# 209     Zimbabwe       6638.0         206.0      97272.0         Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
twenty_countries_lowest_gdp=ten_million_population_df.sort_values('gdp',ascending=True)[['location','gdp']].head(20)
twenty_countries_lowest_gdp
# Out:
#          location           gdp
# 32        Burundi  8.350004e+09
# 176   South Sudan  1.757290e+10
# 85          Haiti  1.885036e+10
# 118        Malawi  2.094810e+10
# 140         Niger  2.241534e+10
# 158        Rwanda  2.401613e+10
# 20          Benin  2.502514e+10
# 82         Guinea  2.625148e+10
# 209      Zimbabwe  2.823622e+10
# 39           Chad  2.904343e+10
# 132    Mozambique  3.550939e+10
# 31   Burkina Faso  3.560041e+10
# 117    Madagascar  3.922267e+10
# 121          Mali  4.079138e+10
# 165       Senegal  4.136722e+10
# 207         Yemen  4.411699e+10
# 33       Cambodia  6.094182e+10
# 208        Zambia  6.782303e+10
# 0     Afghanistan  7.022622e+10
# 135         Nepal  7.117551e+10

# %%
twenty_countries_lowest_hospital_beds=ten_million_population_df.sort_values('hospital_beds_per_thousand',ascending=True)[['location','hospital_beds_per_thousand']].head(20)
twenty_countries_lowest_hospital_beds
# Out:
#          location  hospital_beds_per_thousand
# 121          Mali                        0.10
# 117    Madagascar                        0.20
# 140         Niger                        0.30
# 135         Nepal                        0.30
# 82         Guinea                        0.30
# 63       Ethiopia                        0.30
# 31   Burkina Faso                        0.40
# 195        Uganda                        0.50
# 0     Afghanistan                        0.50
# 20          Benin                        0.50
# 90          India                        0.53
# 80      Guatemala                        0.60
# 145      Pakistan                        0.60
# 85          Haiti                        0.70
# 207         Yemen                        0.70
# 187      Tanzania                        0.70
# 132    Mozambique                        0.70
# 32        Burundi                        0.80
# 33       Cambodia                        0.80
# ...

# %%
common_countries2=twenty_countries_lowest_gdp.merge(twenty_countries_lowest_hospital_beds,on='location',how='inner')
common_countries2.location.count()
# Out:
# 13
